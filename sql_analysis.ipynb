# %%
# import create_engine from sqlalchemy package to connect to MySQL 
from sqlalchemy import create_engine

# %%
# import nbmerge package to merge notebooks
# !pip install nbmerge

# %%
# install ipython-sql library
# !pip install ipython-sql

# %% [markdown]
# Load SQL extension

# %%
# %load_ext sql

# %% [markdown]
# Connect to the AWS RDS bali-hotels database

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# # SQL Analysis

# %% [markdown]
# ## Part 1 Exploratory Queries

# %% [markdown]
# ### 1. How many accomodation listings in Bali does Booking.com host?

# %%
# %%sql
# SELECT COUNT(*) AS hotel_count
# FROM hotels;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 1 rows affected.
# [(755,)]

# %% [markdown]
# #### Insights
# The web scrape of Bali hotels on Booking.com returned 1000 records. However, after data cleaning (e.g. removing duplicates) there are only 755 accomodation listings.

# %% [markdown]
# ### 2. Find the lowest, highest, and average hotel rating

# %%
# %%sql
# SELECT
#     MIN(rating) AS lowest_rating,
#     MAX(rating) AS highest_rating,
#     ROUND(AVG(rating), 2) AS avg_rating
# FROM hotels;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 1 rows affected.
# [(Decimal('0.0'), Decimal('10.0'), Decimal('8.53'))]

# %% [markdown]
# #### Insights
# The lowest rating is 0, the highest is 10, and the average is 8.53. The lowest rating of 0 could be on account of the hotel being a new listing or other external factors. The maximum rating of 10 tells us that this is the highest possible rating a hotel can achieve. For further analysis, we could see how many and which hotels have a perfect rating.

# %% [markdown]
# ### 3. Find the lowest, highest, and average hotel price

# %%
# %%sql
# SELECT
#     MIN(price) AS lowest_price,
#     MAX(price) AS highest_price,
#     ROUND(AVG(price), 2) AS avg_price
# FROM hotels;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 1 rows affected.
# [(Decimal('3'), Decimal('1136'), Decimal('73.76'))]

# %% [markdown]
# #### Insights
# The lowest price for a hotel in Bali is \\$3, the highest is \\$1,136, and the average is \\$73.76.

# %% [markdown]
# ### 4. How many hotels are located in each district?

# %%
# %%sql
# SELECT
#     district_name,
#     COUNT(hotel_id) AS hotel_count_by_district
# FROM hotels h
# JOIN district d
#     ON h.district = d.district_id
# GROUP BY district_name
# ORDER BY hotel_count_by_district DESC;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 60 rows affected.
# [('Ubud', 169),
#  ('Seminyak', 85),
#  ('Canggu', 66),
#  ('Kuta', 51),
#  ('Sanur', 40),
#  ('Legian', 36),
#  ('Nusa Penida', 35),
#  ('Uluwatu', 26),
#  ('Jimbaran', 25),
#  ('Nusa Lembongan', 22),
#  ('Nusa Dua', 20),
#  ('Lovina', 16),
#  ('Denpasar', 15),
#  ('Amed', 15),
#  ('Candidasa', 11),
#  ('Tabanan', 10),
#  ('Kubupenlokan', 8),
#  ('Banyuwedang', 8),
#  ('Pemuteran', 7),
#  ('Tanah Lot', 6),
#  ('Kerobokan', 6),
#  ('Sidemen', 5),
#  ('Keramas', 4),
#  ('Tejakula', 4),
#  ('Sukawati', 4),
#  ('Munduk', 4),
#  ('Tulamben', 4),
#  ('Kintamani', 4),
#  ('Pulukan', 3),
#  ('Payangan', 3),
#  ('Balian', 3),
#  ('Ungasan', 3),
#  ('Bedugul', 3),
#  ('Airsatang', 2),
#  ('Jatiluwih', 2),
#  ('Tegalalang', 2),
#  ('Kesiman', 2),
#  ('Tampaksiring', 2),
#  ('Karangasem', 2),
#  ('Jasri', 2),
#  ('Kubutambahan', 1),
#  ('Klungkung', 1),
#  ('Singaraja', 1),
#  ('Ambengan', 1),
#  ('Penginyahan', 1),
#  ('Penginuman', 1),
#  ('Pesanggaran', 1),
#  ('Banjarangkan', 1),
#  ('Bringkit', 1),
#  ('Badung', 1),
#  ('Buleleng', 1),
#  ('Umeanyar', 1),
#  ('Selemadeg', 1),
#  ('Bangli', 1),
#  ('Dalung', 1),
#  ('Negara', 1),
#  ('Seraya', 1),
#  ('Tirtagangga', 1),
#  ('Gianyar', 1),
#  ('Sempidi', 1)]

# %% [markdown]
# #### Insights
# The top 5 districts with the greatest number of hotels are Ubud, Seminyak, Canggu, Kuta, and Sanur.

# %% [markdown]
# ### 5. What are all the unique subdistrict and district pairings and how many subdistricts does each district have?

# %%
# %%sql
# SELECT
#     subdistrict_id,
#     district_id,
#     subdistrict_name,
#     district_name,
#     COUNT(subdistrict_id) OVER(
#         PARTITION BY district_id
#     ) AS subdistrict_count_by_district
# FROM hotels h
# JOIN district d
#     ON h.district = d.district_id
# JOIN subdistrict s
#     ON h.subdistrict = s.subdistrict_id
# GROUP BY subdistrict_id
# ORDER BY
#     subdistrict_count_by_district DESC,
#     subdistrict_id;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 62 rows affected.
# [(2, 2, 'Pengosekan', 'Ubud', 10),
#  (13, 2, 'Ubud City-Centre', 'Ubud', 10),
#  (15, 2, 'Campuhan', 'Ubud', 10),
#  (16, 2, 'Sambahan', 'Ubud', 10),
#  (17, 2, 'Sayan', 'Ubud', 10),
#  (20, 2, 'Taman', 'Ubud', 10),
#  (30, 2, 'Andong', 'Ubud', 10),
#  (48, 2, 'Penestanan', 'Ubud', 10),
#  (57, 2, 'Kedewatan', 'Ubud', 10),
#  (61, 2, 'Peliatan', 'Ubud', 10),
#  (9, 12, 'Dyanapura', 'Seminyak', 9),
#  (12, 12, 'Petitenget', 'Seminyak', 9),
#  (14, 12, 'Sunset Road', 'Seminyak', 9),
#  (29, 12, 'Batubelig', 'Seminyak', 9),
#  (42, 12, 'Central Seminyak', 'Seminyak', 9),
#  (43, 12, 'Drupadi', 'Seminyak', 9),
#  (46, 12, 'Double Six', 'Seminyak', 9),
#  (52, 12, 'Laksmana', 'Seminyak', 9),
#  (53, 12, 'Nakula', 'Seminyak', 9),
#  (3, 3, 'Berawa', 'Canggu', 8),
#  (25, 3, 'Batu Bolong', 'Canggu', 8),
#  (36, 3, 'Pererenan', 'Canggu', 8),
#  (38, 3, 'Seseh', 'Canggu', 8),
#  (39, 3, 'Umalas', 'Canggu', 8),
#  (41, 3, 'Canggu Beach', 'Canggu', 8),
#  (58, 3, 'Babakan', 'Canggu', 8),
#  (62, 3, 'Padonan', 'Canggu', 8),
#  (6, 7, 'Kampial', 'Nusa Dua', 6),
#  (10, 7, 'Kutuh', 'Nusa Dua', 6),
#  (23, 7, 'Tanjung Benoa', 'Nusa Dua', 6),
#  (32, 7, 'BTDC', 'Nusa Dua', 6),
#  (45, 7, 'Sawangan', 'Nusa Dua', 6),
#  (55, 7, 'Mumbul', 'Nusa Dua', 6),
#  (1, 1, 'Raya Kuta', 'Kuta', 5),
#  (4, 1, 'Kartika Plaza', 'Kuta', 5),
#  (21, 1, 'By Pass Ngurah Rai Kuta', 'Kuta', 5),
#  (22, 1, 'Tuban', 'Kuta', 5),
#  (27, 1, 'Downtown Kuta', 'Kuta', 5),
#  (31, 34, 'Ungasan', 'Uluwatu', 5),
#  (33, 34, 'Pecatu', 'Uluwatu', 5),
#  (35, 34, 'Padang Padang', 'Uluwatu', 5),
#  (49, 34, 'Bingin', 'Uluwatu', 5),
#  (59, 34, 'Suluban', 'Uluwatu', 5),
#  (5, 6, 'Padma', 'Legian', 4),
#  (8, 10, 'Jimbaran Bay', 'Jimbaran', 4),
#  (11, 6, 'Legian City-Centre', 'Legian', 4),
#  (18, 10, 'Balangan', 'Jimbaran', 4),
#  (19, 24, 'Diponegoro', 'Denpasar', 4),
#  (34, 10, 'Bukit', 'Jimbaran', 4),
#  (37, 24, 'Gatot Subroto', 'Denpasar', 4),
#  (40, 6, 'Dewi Sri', 'Legian', 4),
#  (44, 6, 'North Legian', 'Legian', 4),
#  (47, 10, 'By Pass Ngurah Rai', 'Jimbaran', 4),
#  (56, 24, 'Renon', 'Denpasar', 4),
#  (60, 24, 'Teuku Umar', 'Denpasar', 4),
#  (28, 33, 'Mushroom Bay', 'Nusa Lembongan', 3),
#  (50, 33, 'Jungut Batu', 'Nusa Lembongan', 3),
#  (51, 33, 'Nusa Ceningan', 'Nusa Lembongan', 3),
#  (7, 8, 'Sanur Beach', 'Sanur', 1),
#  (24, 28, 'Lovina Beach', 'Lovina', 1),
#  (26, 30, 'Balian Beach', 'Selemadeg', 1),
#  (54, 20, 'Medewi', 'Pulukan', 1)]

# %% [markdown]
# #### Insights
# The top 3 districts with the highest number of subdistricts match the top 3 districts with the greatest number of hotels from the previous query.

# %% [markdown]
# ## Part 2 Primary and Related Questions

# %% [markdown]
# ### Business Problem
# Booking.com wants to improve their customer experience by launching a new service to offer customers a helping hand in picking out the perfect hotel with our travel specialists. Instead of searching through filters and browsing through pages of hotels we want to test a new service that offers a personalised experience for each guest. Test this concept by curating a list of hotels for Customer X's trip.
#
# ### Customer X's Background, Preferences, and Requests
# 1. Tourist planning a solo trip to Bali
# 2. Overwhelmed by the choices on Booking.com
# 3. Prefers staying in popular areas
# 4. Willing to splurge and wants to treat themselves (first post-pandemic holiday!)

# %% [markdown]
# ### 1. Identify the rating category for all hotels
#
# #### Business Justification
# Assigning a descriptive word to the rating numbers will help us in this scenario where customers are more likely to provide their preferences and requests in terms of words rather than numbers.

# %%
# %%sql
# CREATE OR REPLACE VIEW hotel_rating_category AS
#     SELECT
#         hotel_id,
#         price,
#         rating,
#         CASE
#             WHEN rating > 8 THEN 'Wonderful'
#             WHEN rating > 7 THEN 'Very Good'
#             WHEN rating > 6 THEN 'Good'
#             WHEN rating > 5 THEN 'Pleasant'
#         ELSE 'Unsatisfactory' END AS rating_category
#     FROM hotels h;
#
# SELECT *
# FROM hotel_rating_category;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 755 rows affected.
# [(1, Decimal('18'), Decimal('8.1'), 'Wonderful'),
#  (2, Decimal('42'), Decimal('9.4'), 'Wonderful'),
#  (3, Decimal('116'), Decimal('7.5'), 'Very Good'),
#  (4, Decimal('17'), Decimal('9.4'), 'Wonderful'),
#  (5, Decimal('81'), Decimal('8.6'), 'Wonderful'),
#  (6, Decimal('92'), Decimal('9.3'), 'Wonderful'),
#  (7, Decimal('121'), Decimal('9.2'), 'Wonderful'),
#  (8, Decimal('50'), Decimal('8.9'), 'Wonderful'),
#  (9, Decimal('104'), Decimal('9.4'), 'Wonderful'),
#  (10, Decimal('20'), Decimal('7.6'), 'Very Good'),
#  (11, Decimal('16'), Decimal('8.9'), 'Wonderful'),
#  (12, Decimal('25'), Decimal('8.8'), 'Wonderful'),
#  (13, Decimal('147'), Decimal('8.7'), 'Wonderful'),
#  (14, Decimal('73'), Decimal('8.3'), 'Wonderful'),
#  (15, Decimal('39'), Decimal('7.6'), 'Very Good'),
#  (16, Decimal('40'), Decimal('9.0'), 'Wonderful'),
#  (17, Decimal('158'), Decimal('8.3'), 'Wonderful'),
#  (18, Decimal('109'), Decimal('9.0'), 'Wonderful'),
#  (19, Decimal('107'), Decimal('8.8'), 'Wonderful'),
#  (20, Decimal('126'), Decimal('9.2'), 'Wonderful'),
#  (21, Decimal('19'), Decimal('8.5'), 'Wonderful'),
#  (22, Decimal('33'), Decimal('9.2'), 'Wonderful'),
#  (23, Decimal('36'), Decimal('7.9'), 'Very Good'),
#  (24, Decimal('99'), Decimal('8.0'), 'Very Good'),
#  (25, Decimal('39'), Decimal('7.9'), 'Very Good'),
#  (26, Decimal('128'), Decimal('9.2'), 'Wonderful'),
#  (27, Decimal('25'), Decimal('8.6'), 'Wonderful'),
#  (28, Decimal('498'), Decimal('9.5'), 'Wonderful'),
#  (29, Decimal('28'), Decimal('8.8'), 'Wonderful'),
#  (30, Decimal('14'), Decimal('9.4'), 'Wonderful'),
#  (31, Decimal('19'), Decimal('9.8'), 'Wonderful'),
#  (32, Decimal('70'), Decimal('9.5'), 'Wonderful'),
#  (33, Decimal('23'), Decimal('8.0'), 'Very Good'),
#  (34, Decimal('132'), Decimal('9.4'), 'Wonderful'),
#  (35, Decimal('37'), Decimal('8.8'), 'Wonderful'),
#  (36, Decimal('43'), Decimal('9.7'), 'Wonderful'),
#  (37, Decimal('42'), Decimal('8.4'), 'Wonderful'),
#  (38, Decimal('21'), Decimal('9.3'), 'Wonderful'),
#  (39, Decimal('270'), Decimal('9.2'), 'Wonderful'),
#  (40, Decimal('34'), Decimal('8.6'), 'Wonderful'),
#  (41, Decimal('12'), Decimal('8.1'), 'Wonderful'),
#  (42, Decimal('108'), Decimal('9.2'), 'Wonderful'),
#  (43, Decimal('80'), Decimal('9.3'), 'Wonderful'),
#  (44, Decimal('53'), Decimal('8.8'), 'Wonderful'),
#  (45, Decimal('48'), Decimal('9.1'), 'Wonderful'),
#  (46, Decimal('61'), Decimal('9.1'), 'Wonderful'),
#  (47, Decimal('19'), Decimal('9.5'), 'Wonderful'),
#  (48, Decimal('118'), Decimal('9.4'), 'Wonderful'),
#  (49, Decimal('65'), Decimal('9.0'), 'Wonderful'),
#  (50, Decimal('71'), Decimal('9.0'), 'Wonderful'),
#  (51, Decimal('76'), Decimal('9.1'), 'Wonderful'),
#  (52, Decimal('94'), Decimal('8.7'), 'Wonderful'),
#  (53, Decimal('44'), Decimal('8.2'), 'Wonderful'),
#  (54, Decimal('49'), Decimal('10.0'), 'Wonderful'),
#  (55, Decimal('15'), Decimal('7.6'), 'Very Good'),
#  (56, Decimal('18'), Decimal('7.7'), 'Very Good'),
#  (57, Decimal('12'), Decimal('8.9'), 'Wonderful'),
#  (58, Decimal('40'), Decimal('9.3'), 'Wonderful'),
#  (59, Decimal('9'), Decimal('8.3'), 'Wonderful'),
#  (60, Decimal('24'), Decimal('9.0'), 'Wonderful'),
#  (61, Decimal('24'), Decimal('8.4'), 'Wonderful'),
#  (62, Decimal('19'), Decimal('8.5'), 'Wonderful'),
#  (63, Decimal('18'), Decimal('9.4'), 'Wonderful'),
#  (64, Decimal('79'), Decimal('9.2'), 'Wonderful'),
#  (65, Decimal('8'), Decimal('9.0'), 'Wonderful'),
#  (66, Decimal('70'), Decimal('8.4'), 'Wonderful'),
#  (67, Decimal('62'), Decimal('7.6'), 'Very Good'),
#  (68, Decimal('86'), Decimal('8.8'), 'Wonderful'),
#  (69, Decimal('37'), Decimal('9.1'), 'Wonderful'),
#  (70, Decimal('20'), Decimal('8.2'), 'Wonderful'),
#  (71, Decimal('33'), Decimal('8.0'), 'Very Good'),
#  (72, Decimal('11'), Decimal('7.4'), 'Very Good'),
#  (73, Decimal('16'), Decimal('8.9'), 'Wonderful'),
#  (74, Decimal('37'), Decimal('7.6'), 'Very Good'),
#  (75, Decimal('16'), Decimal('8.5'), 'Wonderful'),
#  (76, Decimal('46'), Decimal('9.4'), 'Wonderful'),
#  (77, Decimal('133'), Decimal('7.8'), 'Very Good'),
#  (78, Decimal('172'), Decimal('9.3'), 'Wonderful'),
#  (79, Decimal('50'), Decimal('8.2'), 'Wonderful'),
#  (80, Decimal('44'), Decimal('9.2'), 'Wonderful'),
#  (81, Decimal('46'), Decimal('9.5'), 'Wonderful'),
#  (82, Decimal('127'), Decimal('9.0'), 'Wonderful'),
#  (83, Decimal('175'), Decimal('9.5'), 'Wonderful'),
#  (84, Decimal('171'), Decimal('9.4'), 'Wonderful'),
#  (85, Decimal('55'), Decimal('8.8'), 'Wonderful'),
#  (86, Decimal('186'), Decimal('9.5'), 'Wonderful'),
#  (87, Decimal('148'), Decimal('9.3'), 'Wonderful'),
#  (88, Decimal('137'), Decimal('9.2'), 'Wonderful'),
#  (89, Decimal('77'), Decimal('9.0'), 'Wonderful'),
#  (90, Decimal('101'), Decimal('9.6'), 'Wonderful'),
#  (91, Decimal('35'), Decimal('9.3'), 'Wonderful'),
#  (92, Decimal('201'), Decimal('9.1'), 'Wonderful'),
#  (93, Decimal('95'), Decimal('8.7'), 'Wonderful'),
#  (94, Decimal('63'), Decimal('8.2'), 'Wonderful'),
#  (95, Decimal('156'), Decimal('9.4'), 'Wonderful'),
#  (96, Decimal('62'), Decimal('8.9'), 'Wonderful'),
#  (97, Decimal('605'), Decimal('9.0'), 'Wonderful'),
#  (98, Decimal('118'), Decimal('9.1'), 'Wonderful'),
#  (99, Decimal('125'), Decimal('9.2'), 'Wonderful'),
#  (100, Decimal('34'), Decimal('8.5'), 'Wonderful'),
#  (101, Decimal('25'), Decimal('8.2'), 'Wonderful'),
#  (102, Decimal('262'), Decimal('9.3'), 'Wonderful'),
#  (103, Decimal('31'), Decimal('9.0'), 'Wonderful'),
#  (104, Decimal('36'), Decimal('8.4'), 'Wonderful'),
#  (105, Decimal('264'), Decimal('9.2'), 'Wonderful'),
#  (106, Decimal('183'), Decimal('9.0'), 'Wonderful'),
#  (107, Decimal('45'), Decimal('8.9'), 'Wonderful'),
#  (108, Decimal('90'), Decimal('8.9'), 'Wonderful'),
#  (109, Decimal('60'), Decimal('9.3'), 'Wonderful'),
#  (110, Decimal('264'), Decimal('8.9'), 'Wonderful'),
#  (111, Decimal('15'), Decimal('0.0'), 'Unsatisfactory'),
#  (112, Decimal('159'), Decimal('9.3'), 'Wonderful'),
#  (113, Decimal('181'), Decimal('9.3'), 'Wonderful'),
#  (114, Decimal('260'), Decimal('9.4'), 'Wonderful'),
#  (115, Decimal('40'), Decimal('9.1'), 'Wonderful'),
#  (116, Decimal('106'), Decimal('9.1'), 'Wonderful'),
#  (117, Decimal('259'), Decimal('8.9'), 'Wonderful'),
#  (118, Decimal('64'), Decimal('8.9'), 'Wonderful'),
#  (119, Decimal('195'), Decimal('9.3'), 'Wonderful'),
#  (120, Decimal('669'), Decimal('9.5'), 'Wonderful'),
#  (121, Decimal('142'), Decimal('8.4'), 'Wonderful'),
#  (122, Decimal('32'), Decimal('7.5'), 'Very Good'),
#  (123, Decimal('97'), Decimal('9.6'), 'Wonderful'),
#  (124, Decimal('26'), Decimal('8.3'), 'Wonderful'),
#  (125, Decimal('110'), Decimal('9.4'), 'Wonderful'),
#  (126, Decimal('181'), Decimal('9.1'), 'Wonderful'),
#  (127, Decimal('75'), Decimal('8.5'), 'Wonderful'),
#  (128, Decimal('46'), Decimal('9.0'), 'Wonderful'),
#  (129, Decimal('26'), Decimal('8.7'), 'Wonderful'),
#  (130, Decimal('110'), Decimal('9.4'), 'Wonderful'),
#  (131, Decimal('59'), Decimal('9.0'), 'Wonderful'),
#  (132, Decimal('169'), Decimal('9.3'), 'Wonderful'),
#  (133, Decimal('36'), Decimal('8.8'), 'Wonderful'),
#  (134, Decimal('16'), Decimal('8.7'), 'Wonderful'),
#  (135, Decimal('44'), Decimal('9.1'), 'Wonderful'),
#  (136, Decimal('322'), Decimal('7.9'), 'Very Good'),
#  (137, Decimal('59'), Decimal('9.4'), 'Wonderful'),
#  (138, Decimal('37'), Decimal('8.7'), 'Wonderful'),
#  (139, Decimal('56'), Decimal('8.9'), 'Wonderful'),
#  (140, Decimal('16'), Decimal('8.5'), 'Wonderful'),
#  (141, Decimal('75'), Decimal('9.3'), 'Wonderful'),
#  (142, Decimal('10'), Decimal('7.4'), 'Very Good'),
#  (143, Decimal('72'), Decimal('9.4'), 'Wonderful'),
#  (144, Decimal('167'), Decimal('8.9'), 'Wonderful'),
#  (145, Decimal('10'), Decimal('8.3'), 'Wonderful'),
#  (146, Decimal('132'), Decimal('8.9'), 'Wonderful'),
#  (147, Decimal('24'), Decimal('9.2'), 'Wonderful'),
#  (148, Decimal('76'), Decimal('9.5'), 'Wonderful'),
#  (149, Decimal('13'), Decimal('8.9'), 'Wonderful'),
#  (150, Decimal('530'), Decimal('9.7'), 'Wonderful'),
#  (151, Decimal('61'), Decimal('8.1'), 'Wonderful'),
#  (152, Decimal('97'), Decimal('8.9'), 'Wonderful'),
#  (153, Decimal('97'), Decimal('8.5'), 'Wonderful'),
#  (154, Decimal('80'), Decimal('8.2'), 'Wonderful'),
#  (155, Decimal('19'), Decimal('8.4'), 'Wonderful'),
#  (156, Decimal('56'), Decimal('8.3'), 'Wonderful'),
#  (157, Decimal('12'), Decimal('6.9'), 'Good'),
#  (158, Decimal('87'), Decimal('9.4'), 'Wonderful'),
#  (159, Decimal('10'), Decimal('7.4'), 'Very Good'),
#  (160, Decimal('8'), Decimal('9.0'), 'Wonderful'),
#  (161, Decimal('112'), Decimal('9.1'), 'Wonderful'),
#  (162, Decimal('12'), Decimal('9.0'), 'Wonderful'),
#  (163, Decimal('18'), Decimal('7.6'), 'Very Good'),
#  (164, Decimal('13'), Decimal('9.3'), 'Wonderful'),
#  (165, Decimal('20'), Decimal('8.2'), 'Wonderful'),
#  (166, Decimal('21'), Decimal('9.3'), 'Wonderful'),
#  (167, Decimal('29'), Decimal('7.5'), 'Very Good'),
#  (168, Decimal('131'), Decimal('8.8'), 'Wonderful'),
#  (169, Decimal('71'), Decimal('0.0'), 'Unsatisfactory'),
#  (170, Decimal('35'), Decimal('9.6'), 'Wonderful'),
#  (171, Decimal('13'), Decimal('8.4'), 'Wonderful'),
#  (172, Decimal('8'), Decimal('8.6'), 'Wonderful'),
#  (173, Decimal('15'), Decimal('8.8'), 'Wonderful'),
#  (174, Decimal('75'), Decimal('9.1'), 'Wonderful'),
#  (175, Decimal('23'), Decimal('8.6'), 'Wonderful'),
#  (176, Decimal('164'), Decimal('0.0'), 'Unsatisfactory'),
#  (177, Decimal('5'), Decimal('8.6'), 'Wonderful'),
#  (178, Decimal('22'), Decimal('7.7'), 'Very Good'),
#  (179, Decimal('34'), Decimal('8.6'), 'Wonderful'),
#  (180, Decimal('35'), Decimal('8.7'), 'Wonderful'),
#  (181, Decimal('56'), Decimal('8.9'), 'Wonderful'),
#  (182, Decimal('52'), Decimal('9.4'), 'Wonderful'),
#  (183, Decimal('35'), Decimal('8.7'), 'Wonderful'),
#  (184, Decimal('13'), Decimal('9.4'), 'Wonderful'),
#  (185, Decimal('20'), Decimal('8.5'), 'Wonderful'),
#  (186, Decimal('4'), Decimal('8.2'), 'Wonderful'),
#  (187, Decimal('15'), Decimal('9.3'), 'Wonderful'),
#  (188, Decimal('28'), Decimal('9.6'), 'Wonderful'),
#  (189, Decimal('10'), Decimal('8.5'), 'Wonderful'),
#  (190, Decimal('10'), Decimal('7.6'), 'Very Good'),
#  (191, Decimal('7'), Decimal('6.1'), 'Good'),
#  (192, Decimal('10'), Decimal('9.1'), 'Wonderful'),
#  (193, Decimal('9'), Decimal('8.0'), 'Very Good'),
#  (194, Decimal('3'), Decimal('7.1'), 'Very Good'),
#  (195, Decimal('9'), Decimal('6.5'), 'Good'),
#  (196, Decimal('16'), Decimal('9.4'), 'Wonderful'),
#  (197, Decimal('13'), Decimal('8.8'), 'Wonderful'),
#  (198, Decimal('7'), Decimal('6.0'), 'Pleasant'),
#  (199, Decimal('11'), Decimal('6.3'), 'Good'),
#  (200, Decimal('13'), Decimal('6.8'), 'Good'),
#  (201, Decimal('12'), Decimal('8.5'), 'Wonderful'),
#  (202, Decimal('59'), Decimal('7.8'), 'Very Good'),
#  (203, Decimal('41'), Decimal('9.5'), 'Wonderful'),
#  (204, Decimal('8'), Decimal('6.3'), 'Good'),
#  (205, Decimal('19'), Decimal('8.6'), 'Wonderful'),
#  (206, Decimal('5'), Decimal('8.3'), 'Wonderful'),
#  (207, Decimal('166'), Decimal('8.2'), 'Wonderful'),
#  (208, Decimal('132'), Decimal('8.8'), 'Wonderful'),
#  (209, Decimal('31'), Decimal('8.6'), 'Wonderful'),
#  (210, Decimal('31'), Decimal('9.1'), 'Wonderful'),
#  (211, Decimal('27'), Decimal('9.6'), 'Wonderful'),
#  (212, Decimal('67'), Decimal('9.0'), 'Wonderful'),
#  (213, Decimal('39'), Decimal('8.2'), 'Wonderful'),
#  (214, Decimal('15'), Decimal('7.6'), 'Very Good'),
#  (215, Decimal('72'), Decimal('9.0'), 'Wonderful'),
#  (216, Decimal('141'), Decimal('8.7'), 'Wonderful'),
#  (217, Decimal('31'), Decimal('9.2'), 'Wonderful'),
#  (218, Decimal('37'), Decimal('8.5'), 'Wonderful'),
#  (219, Decimal('6'), Decimal('9.1'), 'Wonderful'),
#  (220, Decimal('76'), Decimal('8.1'), 'Wonderful'),
#  (221, Decimal('35'), Decimal('8.3'), 'Wonderful'),
#  (222, Decimal('29'), Decimal('7.3'), 'Very Good'),
#  (223, Decimal('78'), Decimal('9.0'), 'Wonderful'),
#  (224, Decimal('15'), Decimal('8.1'), 'Wonderful'),
#  (225, Decimal('15'), Decimal('8.5'), 'Wonderful'),
#  (226, Decimal('30'), Decimal('8.4'), 'Wonderful'),
#  (227, Decimal('27'), Decimal('9.0'), 'Wonderful'),
#  (228, Decimal('34'), Decimal('9.1'), 'Wonderful'),
#  (229, Decimal('15'), Decimal('7.9'), 'Very Good'),
#  (230, Decimal('48'), Decimal('8.4'), 'Wonderful'),
#  (231, Decimal('30'), Decimal('8.9'), 'Wonderful'),
#  (232, Decimal('122'), Decimal('8.4'), 'Wonderful'),
#  (233, Decimal('183'), Decimal('9.1'), 'Wonderful'),
#  (234, Decimal('32'), Decimal('9.4'), 'Wonderful'),
#  (235, Decimal('85'), Decimal('8.9'), 'Wonderful'),
#  (236, Decimal('41'), Decimal('7.8'), 'Very Good'),
#  (237, Decimal('30'), Decimal('8.1'), 'Wonderful'),
#  (238, Decimal('48'), Decimal('8.8'), 'Wonderful'),
#  (239, Decimal('136'), Decimal('9.2'), 'Wonderful'),
#  (240, Decimal('24'), Decimal('9.3'), 'Wonderful'),
#  (241, Decimal('68'), Decimal('8.2'), 'Wonderful'),
#  (242, Decimal('10'), Decimal('9.2'), 'Wonderful'),
#  (243, Decimal('22'), Decimal('8.5'), 'Wonderful'),
#  (244, Decimal('67'), Decimal('9.7'), 'Wonderful'),
#  (245, Decimal('41'), Decimal('8.5'), 'Wonderful'),
#  (246, Decimal('39'), Decimal('9.3'), 'Wonderful'),
#  (247, Decimal('18'), Decimal('8.7'), 'Wonderful'),
#  (248, Decimal('45'), Decimal('9.6'), 'Wonderful'),
#  (249, Decimal('22'), Decimal('8.0'), 'Very Good'),
#  (250, Decimal('12'), Decimal('8.4'), 'Wonderful'),
#  (251, Decimal('31'), Decimal('8.4'), 'Wonderful'),
#  (252, Decimal('33'), Decimal('8.5'), 'Wonderful'),
#  (253, Decimal('175'), Decimal('9.3'), 'Wonderful'),
#  (254, Decimal('55'), Decimal('9.2'), 'Wonderful'),
#  (255, Decimal('221'), Decimal('8.9'), 'Wonderful'),
#  (256, Decimal('231'), Decimal('9.0'), 'Wonderful'),
#  (257, Decimal('117'), Decimal('9.1'), 'Wonderful'),
#  (258, Decimal('40'), Decimal('8.1'), 'Wonderful'),
#  (259, Decimal('43'), Decimal('9.6'), 'Wonderful'),
#  (260, Decimal('22'), Decimal('7.8'), 'Very Good'),
#  (261, Decimal('42'), Decimal('8.2'), 'Wonderful'),
#  (262, Decimal('69'), Decimal('8.4'), 'Wonderful'),
#  (263, Decimal('31'), Decimal('8.8'), 'Wonderful'),
#  (264, Decimal('55'), Decimal('8.2'), 'Wonderful'),
#  (265, Decimal('27'), Decimal('9.2'), 'Wonderful'),
#  (266, Decimal('23'), Decimal('8.6'), 'Wonderful'),
#  (267, Decimal('42'), Decimal('8.3'), 'Wonderful'),
#  (268, Decimal('8'), Decimal('7.9'), 'Very Good'),
#  (269, Decimal('16'), Decimal('8.0'), 'Very Good'),
#  (270, Decimal('76'), Decimal('8.9'), 'Wonderful'),
#  (271, Decimal('24'), Decimal('8.0'), 'Very Good'),
#  (272, Decimal('15'), Decimal('8.6'), 'Wonderful'),
#  (273, Decimal('113'), Decimal('8.7'), 'Wonderful'),
#  (274, Decimal('135'), Decimal('8.9'), 'Wonderful'),
#  (275, Decimal('60'), Decimal('8.7'), 'Wonderful'),
#  (276, Decimal('46'), Decimal('8.4'), 'Wonderful'),
#  (277, Decimal('19'), Decimal('8.2'), 'Wonderful'),
#  (278, Decimal('30'), Decimal('8.7'), 'Wonderful'),
#  (279, Decimal('16'), Decimal('8.6'), 'Wonderful'),
#  (280, Decimal('16'), Decimal('8.6'), 'Wonderful'),
#  (281, Decimal('29'), Decimal('9.2'), 'Wonderful'),
#  (282, Decimal('16'), Decimal('8.5'), 'Wonderful'),
#  (283, Decimal('23'), Decimal('7.8'), 'Very Good'),
#  (284, Decimal('20'), Decimal('8.9'), 'Wonderful'),
#  (285, Decimal('11'), Decimal('9.3'), 'Wonderful'),
#  (286, Decimal('19'), Decimal('9.2'), 'Wonderful'),
#  (287, Decimal('60'), Decimal('9.0'), 'Wonderful'),
#  (288, Decimal('25'), Decimal('8.4'), 'Wonderful'),
#  (289, Decimal('47'), Decimal('8.8'), 'Wonderful'),
#  (290, Decimal('11'), Decimal('8.2'), 'Wonderful'),
#  (291, Decimal('129'), Decimal('9.0'), 'Wonderful'),
#  (292, Decimal('47'), Decimal('8.2'), 'Wonderful'),
#  (293, Decimal('24'), Decimal('9.2'), 'Wonderful'),
#  (294, Decimal('16'), Decimal('7.5'), 'Very Good'),
#  (295, Decimal('183'), Decimal('9.1'), 'Wonderful'),
#  (296, Decimal('41'), Decimal('8.2'), 'Wonderful'),
#  (297, Decimal('20'), Decimal('7.3'), 'Very Good'),
#  (298, Decimal('9'), Decimal('7.9'), 'Very Good'),
#  (299, Decimal('29'), Decimal('9.2'), 'Wonderful'),
#  (300, Decimal('8'), Decimal('7.2'), 'Very Good'),
#  (301, Decimal('37'), Decimal('8.4'), 'Wonderful'),
#  (302, Decimal('58'), Decimal('8.9'), 'Wonderful'),
#  (303, Decimal('41'), Decimal('8.5'), 'Wonderful'),
#  (304, Decimal('34'), Decimal('8.6'), 'Wonderful'),
#  (305, Decimal('89'), Decimal('9.2'), 'Wonderful'),
#  (306, Decimal('83'), Decimal('8.2'), 'Wonderful'),
#  (307, Decimal('43'), Decimal('9.1'), 'Wonderful'),
#  (308, Decimal('169'), Decimal('9.3'), 'Wonderful'),
#  (309, Decimal('17'), Decimal('9.7'), 'Wonderful'),
#  (310, Decimal('8'), Decimal('8.6'), 'Wonderful'),
#  (311, Decimal('21'), Decimal('9.0'), 'Wonderful'),
#  (312, Decimal('16'), Decimal('0.0'), 'Unsatisfactory'),
#  (313, Decimal('62'), Decimal('9.5'), 'Wonderful'),
#  (314, Decimal('19'), Decimal('7.2'), 'Very Good'),
#  (315, Decimal('130'), Decimal('8.8'), 'Wonderful'),
#  (316, Decimal('86'), Decimal('8.9'), 'Wonderful'),
#  (317, Decimal('22'), Decimal('8.0'), 'Very Good'),
#  (318, Decimal('367'), Decimal('8.8'), 'Wonderful'),
#  (319, Decimal('98'), Decimal('9.1'), 'Wonderful'),
#  (320, Decimal('236'), Decimal('8.9'), 'Wonderful'),
#  (321, Decimal('31'), Decimal('8.6'), 'Wonderful'),
#  (322, Decimal('33'), Decimal('8.3'), 'Wonderful'),
#  (323, Decimal('60'), Decimal('8.9'), 'Wonderful'),
#  (324, Decimal('18'), Decimal('8.2'), 'Wonderful'),
#  (325, Decimal('29'), Decimal('8.1'), 'Wonderful'),
#  (326, Decimal('41'), Decimal('8.0'), 'Very Good'),
#  (327, Decimal('19'), Decimal('8.7'), 'Wonderful'),
#  (328, Decimal('25'), Decimal('9.2'), 'Wonderful'),
#  (329, Decimal('15'), Decimal('7.6'), 'Very Good'),
#  (330, Decimal('60'), Decimal('9.2'), 'Wonderful'),
#  (331, Decimal('10'), Decimal('8.7'), 'Wonderful'),
#  (332, Decimal('13'), Decimal('7.8'), 'Very Good'),
#  (333, Decimal('33'), Decimal('7.6'), 'Very Good'),
#  (334, Decimal('26'), Decimal('8.5'), 'Wonderful'),
#  (335, Decimal('23'), Decimal('9.1'), 'Wonderful'),
#  (336, Decimal('49'), Decimal('7.6'), 'Very Good'),
#  (337, Decimal('23'), Decimal('8.1'), 'Wonderful'),
#  (338, Decimal('122'), Decimal('8.6'), 'Wonderful'),
#  (339, Decimal('35'), Decimal('8.7'), 'Wonderful'),
#  (340, Decimal('31'), Decimal('7.9'), 'Very Good'),
#  (341, Decimal('198'), Decimal('8.8'), 'Wonderful'),
#  (342, Decimal('41'), Decimal('9.0'), 'Wonderful'),
#  (343, Decimal('112'), Decimal('9.5'), 'Wonderful'),
#  (344, Decimal('38'), Decimal('8.7'), 'Wonderful'),
#  (345, Decimal('31'), Decimal('8.8'), 'Wonderful'),
#  (346, Decimal('15'), Decimal('9.4'), 'Wonderful'),
#  (347, Decimal('20'), Decimal('9.2'), 'Wonderful'),
#  (348, Decimal('66'), Decimal('7.7'), 'Very Good'),
#  (349, Decimal('162'), Decimal('9.2'), 'Wonderful'),
#  (350, Decimal('21'), Decimal('8.0'), 'Very Good'),
#  (351, Decimal('27'), Decimal('8.0'), 'Very Good'),
#  (352, Decimal('46'), Decimal('9.2'), 'Wonderful'),
#  (353, Decimal('31'), Decimal('8.3'), 'Wonderful'),
#  (354, Decimal('43'), Decimal('8.7'), 'Wonderful'),
#  (355, Decimal('55'), Decimal('9.1'), 'Wonderful'),
#  (356, Decimal('55'), Decimal('9.0'), 'Wonderful'),
#  (357, Decimal('28'), Decimal('9.0'), 'Wonderful'),
#  (358, Decimal('26'), Decimal('7.4'), 'Very Good'),
#  (359, Decimal('70'), Decimal('9.1'), 'Wonderful'),
#  (360, Decimal('122'), Decimal('9.5'), 'Wonderful'),
#  (361, Decimal('40'), Decimal('9.2'), 'Wonderful'),
#  (362, Decimal('48'), Decimal('8.3'), 'Wonderful'),
#  (363, Decimal('56'), Decimal('9.3'), 'Wonderful'),
#  (364, Decimal('83'), Decimal('8.6'), 'Wonderful'),
#  (365, Decimal('52'), Decimal('8.8'), 'Wonderful'),
#  (366, Decimal('13'), Decimal('7.5'), 'Very Good'),
#  (367, Decimal('25'), Decimal('7.5'), 'Very Good'),
#  (368, Decimal('84'), Decimal('9.2'), 'Wonderful'),
#  (369, Decimal('21'), Decimal('7.3'), 'Very Good'),
#  (370, Decimal('24'), Decimal('7.3'), 'Very Good'),
#  (371, Decimal('54'), Decimal('8.9'), 'Wonderful'),
#  (372, Decimal('12'), Decimal('7.8'), 'Very Good'),
#  (373, Decimal('43'), Decimal('8.5'), 'Wonderful'),
#  (374, Decimal('43'), Decimal('7.5'), 'Very Good'),
#  (375, Decimal('24'), Decimal('8.8'), 'Wonderful'),
#  (376, Decimal('100'), Decimal('9.1'), 'Wonderful'),
#  (377, Decimal('68'), Decimal('9.0'), 'Wonderful'),
#  (378, Decimal('50'), Decimal('10.0'), 'Wonderful'),
#  (379, Decimal('16'), Decimal('8.5'), 'Wonderful'),
#  (380, Decimal('86'), Decimal('8.3'), 'Wonderful'),
#  (381, Decimal('27'), Decimal('7.8'), 'Very Good'),
#  (382, Decimal('14'), Decimal('8.7'), 'Wonderful'),
#  (383, Decimal('31'), Decimal('8.5'), 'Wonderful'),
#  (384, Decimal('14'), Decimal('8.7'), 'Wonderful'),
#  (385, Decimal('154'), Decimal('9.3'), 'Wonderful'),
#  (386, Decimal('99'), Decimal('8.1'), 'Wonderful'),
#  (387, Decimal('105'), Decimal('7.3'), 'Very Good'),
#  (388, Decimal('55'), Decimal('9.0'), 'Wonderful'),
#  (389, Decimal('17'), Decimal('9.1'), 'Wonderful'),
#  (390, Decimal('25'), Decimal('8.2'), 'Wonderful'),
#  (391, Decimal('38'), Decimal('8.7'), 'Wonderful'),
#  (392, Decimal('40'), Decimal('8.1'), 'Wonderful'),
#  (393, Decimal('139'), Decimal('8.8'), 'Wonderful'),
#  (394, Decimal('42'), Decimal('8.1'), 'Wonderful'),
#  (395, Decimal('21'), Decimal('7.5'), 'Very Good'),
#  (396, Decimal('43'), Decimal('8.7'), 'Wonderful'),
#  (397, Decimal('30'), Decimal('8.2'), 'Wonderful'),
#  (398, Decimal('22'), Decimal('8.4'), 'Wonderful'),
#  (399, Decimal('30'), Decimal('8.6'), 'Wonderful'),
#  (400, Decimal('81'), Decimal('8.9'), 'Wonderful'),
#  (401, Decimal('29'), Decimal('8.1'), 'Wonderful'),
#  (402, Decimal('7'), Decimal('8.8'), 'Wonderful'),
#  (403, Decimal('15'), Decimal('6.6'), 'Good'),
#  (404, Decimal('22'), Decimal('8.4'), 'Wonderful'),
#  (405, Decimal('91'), Decimal('8.8'), 'Wonderful'),
#  (406, Decimal('72'), Decimal('9.2'), 'Wonderful'),
#  (407, Decimal('76'), Decimal('8.7'), 'Wonderful'),
#  (408, Decimal('63'), Decimal('8.2'), 'Wonderful'),
#  (409, Decimal('21'), Decimal('9.1'), 'Wonderful'),
#  (410, Decimal('21'), Decimal('8.1'), 'Wonderful'),
#  (411, Decimal('17'), Decimal('8.5'), 'Wonderful'),
#  (412, Decimal('24'), Decimal('8.5'), 'Wonderful'),
#  (413, Decimal('42'), Decimal('7.8'), 'Very Good'),
#  (414, Decimal('199'), Decimal('8.8'), 'Wonderful'),
#  (415, Decimal('18'), Decimal('7.6'), 'Very Good'),
#  (416, Decimal('21'), Decimal('8.6'), 'Wonderful'),
#  (417, Decimal('34'), Decimal('8.4'), 'Wonderful'),
#  (418, Decimal('24'), Decimal('9.0'), 'Wonderful'),
#  (419, Decimal('110'), Decimal('9.6'), 'Wonderful'),
#  (420, Decimal('84'), Decimal('8.0'), 'Very Good'),
#  (421, Decimal('42'), Decimal('8.7'), 'Wonderful'),
#  (422, Decimal('15'), Decimal('7.8'), 'Very Good'),
#  (423, Decimal('21'), Decimal('8.5'), 'Wonderful'),
#  (424, Decimal('81'), Decimal('7.8'), 'Very Good'),
#  (425, Decimal('31'), Decimal('8.6'), 'Wonderful'),
#  (426, Decimal('287'), Decimal('9.4'), 'Wonderful'),
#  (427, Decimal('40'), Decimal('9.4'), 'Wonderful'),
#  (428, Decimal('94'), Decimal('8.9'), 'Wonderful'),
#  (429, Decimal('90'), Decimal('9.4'), 'Wonderful'),
#  (430, Decimal('57'), Decimal('7.9'), 'Very Good'),
#  (431, Decimal('31'), Decimal('7.8'), 'Very Good'),
#  (432, Decimal('16'), Decimal('8.3'), 'Wonderful'),
#  (433, Decimal('230'), Decimal('7.2'), 'Very Good'),
#  (434, Decimal('24'), Decimal('8.5'), 'Wonderful'),
#  (435, Decimal('42'), Decimal('9.2'), 'Wonderful'),
#  (436, Decimal('101'), Decimal('8.8'), 'Wonderful'),
#  (437, Decimal('49'), Decimal('8.3'), 'Wonderful'),
#  (438, Decimal('30'), Decimal('8.9'), 'Wonderful'),
#  (439, Decimal('60'), Decimal('8.9'), 'Wonderful'),
#  (440, Decimal('24'), Decimal('7.8'), 'Very Good'),
#  (441, Decimal('226'), Decimal('9.1'), 'Wonderful'),
#  (442, Decimal('48'), Decimal('8.7'), 'Wonderful'),
#  (443, Decimal('23'), Decimal('9.0'), 'Wonderful'),
#  (444, Decimal('83'), Decimal('8.9'), 'Wonderful'),
#  (445, Decimal('26'), Decimal('7.8'), 'Very Good'),
#  (446, Decimal('63'), Decimal('8.0'), 'Very Good'),
#  (447, Decimal('78'), Decimal('9.1'), 'Wonderful'),
#  (448, Decimal('52'), Decimal('8.2'), 'Wonderful'),
#  (449, Decimal('38'), Decimal('8.8'), 'Wonderful'),
#  (450, Decimal('24'), Decimal('8.1'), 'Wonderful'),
#  (451, Decimal('51'), Decimal('9.2'), 'Wonderful'),
#  (452, Decimal('33'), Decimal('7.8'), 'Very Good'),
#  (453, Decimal('148'), Decimal('8.8'), 'Wonderful'),
#  (454, Decimal('25'), Decimal('8.5'), 'Wonderful'),
#  (455, Decimal('52'), Decimal('8.9'), 'Wonderful'),
#  (456, Decimal('31'), Decimal('8.9'), 'Wonderful'),
#  (457, Decimal('89'), Decimal('9.0'), 'Wonderful'),
#  (458, Decimal('16'), Decimal('8.6'), 'Wonderful'),
#  (459, Decimal('52'), Decimal('9.1'), 'Wonderful'),
#  (460, Decimal('62'), Decimal('8.4'), 'Wonderful'),
#  (461, Decimal('45'), Decimal('9.3'), 'Wonderful'),
#  (462, Decimal('44'), Decimal('8.3'), 'Wonderful'),
#  (463, Decimal('51'), Decimal('9.6'), 'Wonderful'),
#  (464, Decimal('45'), Decimal('7.9'), 'Very Good'),
#  (465, Decimal('15'), Decimal('8.8'), 'Wonderful'),
#  (466, Decimal('45'), Decimal('9.0'), 'Wonderful'),
#  (467, Decimal('116'), Decimal('9.0'), 'Wonderful'),
#  (468, Decimal('15'), Decimal('9.5'), 'Wonderful'),
#  (469, Decimal('25'), Decimal('8.2'), 'Wonderful'),
#  (470, Decimal('32'), Decimal('8.9'), 'Wonderful'),
#  (471, Decimal('53'), Decimal('8.9'), 'Wonderful'),
#  (472, Decimal('84'), Decimal('8.2'), 'Wonderful'),
#  (473, Decimal('19'), Decimal('8.7'), 'Wonderful'),
#  (474, Decimal('24'), Decimal('8.5'), 'Wonderful'),
#  (475, Decimal('49'), Decimal('8.3'), 'Wonderful'),
#  (476, Decimal('41'), Decimal('9.2'), 'Wonderful'),
#  (477, Decimal('86'), Decimal('9.1'), 'Wonderful'),
#  (478, Decimal('24'), Decimal('8.2'), 'Wonderful'),
#  (479, Decimal('63'), Decimal('7.7'), 'Very Good'),
#  (480, Decimal('26'), Decimal('9.2'), 'Wonderful'),
#  (481, Decimal('19'), Decimal('8.8'), 'Wonderful'),
#  (482, Decimal('24'), Decimal('8.5'), 'Wonderful'),
#  (483, Decimal('45'), Decimal('9.1'), 'Wonderful'),
#  (484, Decimal('17'), Decimal('8.6'), 'Wonderful'),
#  (485, Decimal('65'), Decimal('8.6'), 'Wonderful'),
#  (486, Decimal('53'), Decimal('9.4'), 'Wonderful'),
#  (487, Decimal('144'), Decimal('8.7'), 'Wonderful'),
#  (488, Decimal('52'), Decimal('8.9'), 'Wonderful'),
#  (489, Decimal('248'), Decimal('9.4'), 'Wonderful'),
#  (490, Decimal('26'), Decimal('9.3'), 'Wonderful'),
#  (491, Decimal('49'), Decimal('8.4'), 'Wonderful'),
#  (492, Decimal('8'), Decimal('0.0'), 'Unsatisfactory'),
#  (493, Decimal('62'), Decimal('8.3'), 'Wonderful'),
#  (494, Decimal('25'), Decimal('8.2'), 'Wonderful'),
#  (495, Decimal('39'), Decimal('8.4'), 'Wonderful'),
#  (496, Decimal('76'), Decimal('9.1'), 'Wonderful'),
#  (497, Decimal('410'), Decimal('8.8'), 'Wonderful'),
#  (498, Decimal('120'), Decimal('8.8'), 'Wonderful'),
#  (499, Decimal('33'), Decimal('8.8'), 'Wonderful'),
#  (500, Decimal('58'), Decimal('8.4'), 'Wonderful'),
#  (501, Decimal('52'), Decimal('8.6'), 'Wonderful'),
#  (502, Decimal('160'), Decimal('8.9'), 'Wonderful'),
#  (503, Decimal('162'), Decimal('9.4'), 'Wonderful'),
#  (504, Decimal('117'), Decimal('9.1'), 'Wonderful'),
#  (505, Decimal('19'), Decimal('7.6'), 'Very Good'),
#  (506, Decimal('113'), Decimal('9.1'), 'Wonderful'),
#  (507, Decimal('37'), Decimal('8.7'), 'Wonderful'),
#  (508, Decimal('48'), Decimal('8.5'), 'Wonderful'),
#  (509, Decimal('26'), Decimal('9.0'), 'Wonderful'),
#  (510, Decimal('152'), Decimal('9.4'), 'Wonderful'),
#  (511, Decimal('52'), Decimal('8.5'), 'Wonderful'),
#  (512, Decimal('61'), Decimal('8.0'), 'Very Good'),
#  (513, Decimal('138'), Decimal('8.9'), 'Wonderful'),
#  (514, Decimal('96'), Decimal('8.7'), 'Wonderful'),
#  (515, Decimal('39'), Decimal('8.6'), 'Wonderful'),
#  (516, Decimal('57'), Decimal('8.7'), 'Wonderful'),
#  (517, Decimal('184'), Decimal('8.9'), 'Wonderful'),
#  (518, Decimal('48'), Decimal('8.8'), 'Wonderful'),
#  (519, Decimal('45'), Decimal('8.7'), 'Wonderful'),
#  (520, Decimal('21'), Decimal('9.3'), 'Wonderful'),
#  (521, Decimal('55'), Decimal('8.2'), 'Wonderful'),
#  (522, Decimal('173'), Decimal('8.8'), 'Wonderful'),
#  (523, Decimal('87'), Decimal('8.6'), 'Wonderful'),
#  (524, Decimal('52'), Decimal('7.4'), 'Very Good'),
#  (525, Decimal('44'), Decimal('9.1'), 'Wonderful'),
#  (526, Decimal('36'), Decimal('7.4'), 'Very Good'),
#  (527, Decimal('70'), Decimal('8.6'), 'Wonderful'),
#  (528, Decimal('24'), Decimal('8.5'), 'Wonderful'),
#  (529, Decimal('75'), Decimal('9.3'), 'Wonderful'),
#  (530, Decimal('45'), Decimal('8.5'), 'Wonderful'),
#  (531, Decimal('131'), Decimal('9.0'), 'Wonderful'),
#  (532, Decimal('128'), Decimal('9.1'), 'Wonderful'),
#  (533, Decimal('66'), Decimal('8.8'), 'Wonderful'),
#  (534, Decimal('123'), Decimal('9.8'), 'Wonderful'),
#  (535, Decimal('34'), Decimal('8.8'), 'Wonderful'),
#  (536, Decimal('27'), Decimal('9.0'), 'Wonderful'),
#  (537, Decimal('579'), Decimal('8.6'), 'Wonderful'),
#  (538, Decimal('13'), Decimal('9.4'), 'Wonderful'),
#  (539, Decimal('125'), Decimal('8.7'), 'Wonderful'),
#  (540, Decimal('42'), Decimal('9.0'), 'Wonderful'),
#  (541, Decimal('27'), Decimal('8.8'), 'Wonderful'),
#  (542, Decimal('69'), Decimal('8.5'), 'Wonderful'),
#  (543, Decimal('43'), Decimal('8.4'), 'Wonderful'),
#  (544, Decimal('23'), Decimal('8.8'), 'Wonderful'),
#  (545, Decimal('25'), Decimal('7.4'), 'Very Good'),
#  (546, Decimal('138'), Decimal('9.2'), 'Wonderful'),
#  (547, Decimal('38'), Decimal('8.2'), 'Wonderful'),
#  (548, Decimal('4'), Decimal('8.7'), 'Wonderful'),
#  (549, Decimal('35'), Decimal('8.8'), 'Wonderful'),
#  (550, Decimal('29'), Decimal('8.4'), 'Wonderful'),
#  (551, Decimal('33'), Decimal('8.1'), 'Wonderful'),
#  (552, Decimal('28'), Decimal('9.0'), 'Wonderful'),
#  (553, Decimal('19'), Decimal('8.8'), 'Wonderful'),
#  (554, Decimal('23'), Decimal('0.0'), 'Unsatisfactory'),
#  (555, Decimal('18'), Decimal('8.6'), 'Wonderful'),
#  (556, Decimal('21'), Decimal('9.1'), 'Wonderful'),
#  (557, Decimal('22'), Decimal('7.3'), 'Very Good'),
#  (558, Decimal('14'), Decimal('7.6'), 'Very Good'),
#  (559, Decimal('5'), Decimal('9.2'), 'Wonderful'),
#  (560, Decimal('179'), Decimal('7.9'), 'Very Good'),
#  (561, Decimal('29'), Decimal('7.9'), 'Very Good'),
#  (562, Decimal('7'), Decimal('9.0'), 'Wonderful'),
#  (563, Decimal('45'), Decimal('0.0'), 'Unsatisfactory'),
#  (564, Decimal('52'), Decimal('9.2'), 'Wonderful'),
#  (565, Decimal('71'), Decimal('9.5'), 'Wonderful'),
#  (566, Decimal('41'), Decimal('9.3'), 'Wonderful'),
#  (567, Decimal('83'), Decimal('8.8'), 'Wonderful'),
#  (568, Decimal('124'), Decimal('9.3'), 'Wonderful'),
#  (569, Decimal('83'), Decimal('8.6'), 'Wonderful'),
#  (570, Decimal('17'), Decimal('8.4'), 'Wonderful'),
#  (571, Decimal('26'), Decimal('8.7'), 'Wonderful'),
#  (572, Decimal('173'), Decimal('8.9'), 'Wonderful'),
#  (573, Decimal('381'), Decimal('9.1'), 'Wonderful'),
#  (574, Decimal('13'), Decimal('7.9'), 'Very Good'),
#  (575, Decimal('67'), Decimal('9.3'), 'Wonderful'),
#  (576, Decimal('57'), Decimal('8.0'), 'Very Good'),
#  (577, Decimal('160'), Decimal('9.6'), 'Wonderful'),
#  (578, Decimal('87'), Decimal('9.1'), 'Wonderful'),
#  (579, Decimal('239'), Decimal('7.3'), 'Very Good'),
#  (580, Decimal('68'), Decimal('8.3'), 'Wonderful'),
#  (581, Decimal('48'), Decimal('9.0'), 'Wonderful'),
#  (582, Decimal('63'), Decimal('9.2'), 'Wonderful'),
#  (583, Decimal('292'), Decimal('9.3'), 'Wonderful'),
#  (584, Decimal('52'), Decimal('9.1'), 'Wonderful'),
#  (585, Decimal('94'), Decimal('8.8'), 'Wonderful'),
#  (586, Decimal('27'), Decimal('7.2'), 'Very Good'),
#  (587, Decimal('79'), Decimal('9.6'), 'Wonderful'),
#  (588, Decimal('28'), Decimal('8.9'), 'Wonderful'),
#  (589, Decimal('116'), Decimal('8.6'), 'Wonderful'),
#  (590, Decimal('22'), Decimal('7.6'), 'Very Good'),
#  (591, Decimal('40'), Decimal('7.9'), 'Very Good'),
#  (592, Decimal('14'), Decimal('8.5'), 'Wonderful'),
#  (593, Decimal('105'), Decimal('9.0'), 'Wonderful'),
#  (594, Decimal('59'), Decimal('8.5'), 'Wonderful'),
#  (595, Decimal('86'), Decimal('7.9'), 'Very Good'),
#  (596, Decimal('20'), Decimal('8.9'), 'Wonderful'),
#  (597, Decimal('16'), Decimal('8.2'), 'Wonderful'),
#  (598, Decimal('28'), Decimal('8.7'), 'Wonderful'),
#  (599, Decimal('61'), Decimal('0.0'), 'Unsatisfactory'),
#  (600, Decimal('19'), Decimal('9.6'), 'Wonderful'),
#  (601, Decimal('34'), Decimal('9.3'), 'Wonderful'),
#  (602, Decimal('99'), Decimal('8.8'), 'Wonderful'),
#  (603, Decimal('40'), Decimal('7.3'), 'Very Good'),
#  (604, Decimal('19'), Decimal('7.7'), 'Very Good'),
#  (605, Decimal('276'), Decimal('9.1'), 'Wonderful'),
#  (606, Decimal('56'), Decimal('8.5'), 'Wonderful'),
#  (607, Decimal('60'), Decimal('8.3'), 'Wonderful'),
#  (608, Decimal('59'), Decimal('8.3'), 'Wonderful'),
#  (609, Decimal('21'), Decimal('9.4'), 'Wonderful'),
#  (610, Decimal('22'), Decimal('8.0'), 'Very Good'),
#  (611, Decimal('31'), Decimal('9.1'), 'Wonderful'),
#  (612, Decimal('23'), Decimal('8.4'), 'Wonderful'),
#  (613, Decimal('300'), Decimal('8.8'), 'Wonderful'),
#  (614, Decimal('81'), Decimal('8.4'), 'Wonderful'),
#  (615, Decimal('19'), Decimal('9.3'), 'Wonderful'),
#  (616, Decimal('31'), Decimal('8.4'), 'Wonderful'),
#  (617, Decimal('29'), Decimal('7.6'), 'Very Good'),
#  (618, Decimal('83'), Decimal('8.9'), 'Wonderful'),
#  (619, Decimal('364'), Decimal('9.2'), 'Wonderful'),
#  (620, Decimal('21'), Decimal('8.1'), 'Wonderful'),
#  (621, Decimal('59'), Decimal('7.8'), 'Very Good'),
#  (622, Decimal('119'), Decimal('8.4'), 'Wonderful'),
#  (623, Decimal('36'), Decimal('8.5'), 'Wonderful'),
#  (624, Decimal('25'), Decimal('8.3'), 'Wonderful'),
#  (625, Decimal('163'), Decimal('8.1'), 'Wonderful'),
#  (626, Decimal('20'), Decimal('8.1'), 'Wonderful'),
#  (627, Decimal('98'), Decimal('8.9'), 'Wonderful'),
#  (628, Decimal('28'), Decimal('9.1'), 'Wonderful'),
#  (629, Decimal('34'), Decimal('7.1'), 'Very Good'),
#  (630, Decimal('20'), Decimal('8.7'), 'Wonderful'),
#  (631, Decimal('27'), Decimal('8.4'), 'Wonderful'),
#  (632, Decimal('22'), Decimal('8.2'), 'Wonderful'),
#  (633, Decimal('27'), Decimal('8.7'), 'Wonderful'),
#  (634, Decimal('34'), Decimal('8.9'), 'Wonderful'),
#  (635, Decimal('27'), Decimal('7.4'), 'Very Good'),
#  (636, Decimal('27'), Decimal('8.6'), 'Wonderful'),
#  (637, Decimal('111'), Decimal('8.9'), 'Wonderful'),
#  (638, Decimal('619'), Decimal('8.9'), 'Wonderful'),
#  (639, Decimal('50'), Decimal('8.2'), 'Wonderful'),
#  (640, Decimal('53'), Decimal('8.8'), 'Wonderful'),
#  (641, Decimal('63'), Decimal('8.7'), 'Wonderful'),
#  (642, Decimal('101'), Decimal('8.9'), 'Wonderful'),
#  (643, Decimal('31'), Decimal('9.8'), 'Wonderful'),
#  (644, Decimal('29'), Decimal('8.0'), 'Very Good'),
#  (645, Decimal('63'), Decimal('7.6'), 'Very Good'),
#  (646, Decimal('56'), Decimal('8.9'), 'Wonderful'),
#  (647, Decimal('27'), Decimal('8.9'), 'Wonderful'),
#  (648, Decimal('17'), Decimal('9.2'), 'Wonderful'),
#  (649, Decimal('241'), Decimal('9.1'), 'Wonderful'),
#  (650, Decimal('38'), Decimal('8.2'), 'Wonderful'),
#  (651, Decimal('95'), Decimal('9.5'), 'Wonderful'),
#  (652, Decimal('95'), Decimal('8.2'), 'Wonderful'),
#  (653, Decimal('38'), Decimal('8.8'), 'Wonderful'),
#  (654, Decimal('25'), Decimal('7.6'), 'Very Good'),
#  (655, Decimal('25'), Decimal('8.1'), 'Wonderful'),
#  (656, Decimal('10'), Decimal('9.1'), 'Wonderful'),
#  (657, Decimal('188'), Decimal('9.1'), 'Wonderful'),
#  (658, Decimal('17'), Decimal('9.4'), 'Wonderful'),
#  (659, Decimal('20'), Decimal('9.6'), 'Wonderful'),
#  (660, Decimal('64'), Decimal('8.5'), 'Wonderful'),
#  (661, Decimal('277'), Decimal('9.4'), 'Wonderful'),
#  (662, Decimal('19'), Decimal('8.4'), 'Wonderful'),
#  (663, Decimal('272'), Decimal('9.1'), 'Wonderful'),
#  (664, Decimal('27'), Decimal('9.1'), 'Wonderful'),
#  (665, Decimal('21'), Decimal('8.3'), 'Wonderful'),
#  (666, Decimal('14'), Decimal('8.6'), 'Wonderful'),
#  (667, Decimal('25'), Decimal('7.9'), 'Very Good'),
#  (668, Decimal('20'), Decimal('7.5'), 'Very Good'),
#  (669, Decimal('32'), Decimal('7.7'), 'Very Good'),
#  (670, Decimal('137'), Decimal('8.5'), 'Wonderful'),
#  (671, Decimal('17'), Decimal('9.2'), 'Wonderful'),
#  (672, Decimal('76'), Decimal('8.7'), 'Wonderful'),
#  (673, Decimal('33'), Decimal('8.2'), 'Wonderful'),
#  (674, Decimal('21'), Decimal('8.7'), 'Wonderful'),
#  (675, Decimal('151'), Decimal('9.6'), 'Wonderful'),
#  (676, Decimal('159'), Decimal('8.9'), 'Wonderful'),
#  (677, Decimal('66'), Decimal('9.2'), 'Wonderful'),
#  (678, Decimal('124'), Decimal('8.8'), 'Wonderful'),
#  (679, Decimal('416'), Decimal('9.4'), 'Wonderful'),
#  (680, Decimal('160'), Decimal('8.2'), 'Wonderful'),
#  (681, Decimal('9'), Decimal('9.4'), 'Wonderful'),
#  (682, Decimal('679'), Decimal('9.3'), 'Wonderful'),
#  (683, Decimal('38'), Decimal('8.9'), 'Wonderful'),
#  (684, Decimal('15'), Decimal('7.8'), 'Very Good'),
#  (685, Decimal('338'), Decimal('9.2'), 'Wonderful'),
#  (686, Decimal('33'), Decimal('9.4'), 'Wonderful'),
#  (687, Decimal('21'), Decimal('7.3'), 'Very Good'),
#  (688, Decimal('386'), Decimal('9.3'), 'Wonderful'),
#  (689, Decimal('67'), Decimal('8.1'), 'Wonderful'),
#  (690, Decimal('40'), Decimal('9.6'), 'Wonderful'),
#  (691, Decimal('22'), Decimal('9.0'), 'Wonderful'),
#  (692, Decimal('116'), Decimal('9.6'), 'Wonderful'),
#  (693, Decimal('38'), Decimal('7.8'), 'Very Good'),
#  (694, Decimal('39'), Decimal('9.1'), 'Wonderful'),
#  (695, Decimal('62'), Decimal('8.3'), 'Wonderful'),
#  (696, Decimal('56'), Decimal('7.4'), 'Very Good'),
#  (697, Decimal('22'), Decimal('8.3'), 'Wonderful'),
#  (698, Decimal('303'), Decimal('9.0'), 'Wonderful'),
#  (699, Decimal('106'), Decimal('9.2'), 'Wonderful'),
#  (700, Decimal('87'), Decimal('7.6'), 'Very Good'),
#  (701, Decimal('15'), Decimal('9.6'), 'Wonderful'),
#  (702, Decimal('39'), Decimal('8.5'), 'Wonderful'),
#  (703, Decimal('144'), Decimal('9.4'), 'Wonderful'),
#  (704, Decimal('16'), Decimal('9.2'), 'Wonderful'),
#  (705, Decimal('7'), Decimal('8.5'), 'Wonderful'),
#  (706, Decimal('62'), Decimal('8.7'), 'Wonderful'),
#  (707, Decimal('103'), Decimal('9.3'), 'Wonderful'),
#  (708, Decimal('90'), Decimal('7.1'), 'Very Good'),
#  (709, Decimal('169'), Decimal('9.2'), 'Wonderful'),
#  (710, Decimal('161'), Decimal('8.8'), 'Wonderful'),
#  (711, Decimal('18'), Decimal('8.1'), 'Wonderful'),
#  (712, Decimal('174'), Decimal('7.9'), 'Very Good'),
#  (713, Decimal('148'), Decimal('6.8'), 'Good'),
#  (714, Decimal('51'), Decimal('8.4'), 'Wonderful'),
#  (715, Decimal('93'), Decimal('8.6'), 'Wonderful'),
#  (716, Decimal('117'), Decimal('8.8'), 'Wonderful'),
#  (717, Decimal('39'), Decimal('7.9'), 'Very Good'),
#  (718, Decimal('384'), Decimal('9.2'), 'Wonderful'),
#  (719, Decimal('139'), Decimal('9.4'), 'Wonderful'),
#  (720, Decimal('35'), Decimal('8.9'), 'Wonderful'),
#  (721, Decimal('72'), Decimal('9.1'), 'Wonderful'),
#  (722, Decimal('538'), Decimal('9.2'), 'Wonderful'),
#  (723, Decimal('33'), Decimal('8.5'), 'Wonderful'),
#  (724, Decimal('72'), Decimal('8.8'), 'Wonderful'),
#  (725, Decimal('268'), Decimal('9.1'), 'Wonderful'),
#  (726, Decimal('90'), Decimal('8.9'), 'Wonderful'),
#  (727, Decimal('14'), Decimal('7.3'), 'Very Good'),
#  (728, Decimal('59'), Decimal('8.2'), 'Wonderful'),
#  (729, Decimal('38'), Decimal('8.5'), 'Wonderful'),
#  (730, Decimal('20'), Decimal('9.2'), 'Wonderful'),
#  (731, Decimal('276'), Decimal('8.0'), 'Very Good'),
#  (732, Decimal('60'), Decimal('9.4'), 'Wonderful'),
#  (733, Decimal('174'), Decimal('8.8'), 'Wonderful'),
#  (734, Decimal('300'), Decimal('8.8'), 'Wonderful'),
#  (735, Decimal('69'), Decimal('9.0'), 'Wonderful'),
#  (736, Decimal('63'), Decimal('8.3'), 'Wonderful'),
#  (737, Decimal('135'), Decimal('9.6'), 'Wonderful'),
#  (738, Decimal('42'), Decimal('7.3'), 'Very Good'),
#  (739, Decimal('1136'), Decimal('9.7'), 'Wonderful'),
#  (740, Decimal('31'), Decimal('8.7'), 'Wonderful'),
#  (741, Decimal('230'), Decimal('9.7'), 'Wonderful'),
#  (742, Decimal('23'), Decimal('9.1'), 'Wonderful'),
#  (743, Decimal('10'), Decimal('0.0'), 'Unsatisfactory'),
#  (744, Decimal('11'), Decimal('4.2'), 'Unsatisfactory'),
#  (745, Decimal('45'), Decimal('8.9'), 'Wonderful'),
#  (746, Decimal('290'), Decimal('9.3'), 'Wonderful'),
#  (747, Decimal('26'), Decimal('9.3'), 'Wonderful'),
#  (748, Decimal('35'), Decimal('8.6'), 'Wonderful'),
#  (749, Decimal('142'), Decimal('9.1'), 'Wonderful'),
#  (750, Decimal('29'), Decimal('9.1'), 'Wonderful'),
#  (751, Decimal('121'), Decimal('9.5'), 'Wonderful'),
#  (752, Decimal('112'), Decimal('0.0'), 'Unsatisfactory'),
#  (753, Decimal('159'), Decimal('9.1'), 'Wonderful'),
#  (754, Decimal('303'), Decimal('9.1'), 'Wonderful'),
#  (755, Decimal('66'), Decimal('7.8'), 'Very Good')]

# %% [markdown]
# #### Recommendations
# Since we have assigned the ratings with their respective category labels for each hotel, we can perform additional queries that group by the rating categories. Next, we should determine the average price for a hotel per rating category.

# %% [markdown]
# ### 2. What is the average price for a hotel per rating category?
#
# #### Business Justification
# Understanding the average price of a hotel per rating category is a starting point to help us understand how much customers can expect to pay for a hotel based on the rating category.

# %%
# %%sql
# CREATE OR REPLACE VIEW avg_price_by_rating_category AS
#     SELECT
#         ROUND(AVG(price), 2) as avg_price,
#         rating_category
#     FROM hotel_rating_category
#     GROUP BY rating_category
#     ORDER BY avg_price DESC;
#
# SELECT *
# FROM avg_price_by_rating_category;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 0 rows affected.
# 5 rows affected.
# [(Decimal('80.19'), 'Wonderful'),
#  (Decimal('48.73'), 'Unsatisfactory'),
#  (Decimal('45.23'), 'Very Good'),
#  (Decimal('27.88'), 'Good'),
#  (Decimal('7.00'), 'Pleasant')]

# %% [markdown]
# #### Recommendations
# 1. There is approximately a 40% difference in average price between Wonderful and Very Good hotels. Surprisingly, the average price for Unsatisfactory hotels are higher than Very Good, Good, and Pleasant hotels. The lowest average price for a rating category is for Pleasant hotels.
#
# 2. The business can consider performing a more in-depth sentiment analysis on hotel reviews to analyse other factors that impact average price. This can help the company factor in more values to provide greater accuracy in match results considering the variety of customers they will serve with this personalised service.

# %% [markdown]
# ### 3a. Which hotels can we recommend to Customer X?
#
# #### Business Justification
# With an understanding of Customer X's background, preferences, and requests, the assigned travel specialist has determined that they should find hotels in the top 3 most popular districts where the rating category is Wonderful or Very Good. We can base the popularity of a district by the number of hotels located in the district. For Wonderful hotels filter hotels where the price is greater than or equal to the average price for a Wonderful hotel. For Very Good hotels, filter for hotels where the price is between the average price for these two categories.

# %%
# %%sql
# SELECT
#     DENSE_RANK() OVER (
#         PARTITION BY district_name
#         ORDER BY rating DESC, h.price
#     ) AS ranking,
#     name,
#     h.rating,
#     h.price,
#     rating_category,
#     subdistrict_name AS subdistrict,
#     district_name AS district,
#     link
# FROM hotels h
# JOIN district d
#     ON h.district = d.district_id
# JOIN subdistrict s
#     ON h.subdistrict = s.subdistrict_id
# JOIN hotel_rating_category hs
#     ON h.hotel_id = hs.hotel_id
# WHERE district_name IN ('Ubud', 'Seminyak', 'Canggu')
#     AND CASE
#             WHEN rating_category = 'Wonderful' THEN h.price >=
#                 (SELECT avg_price FROM avg_price_by_rating_category WHERE rating_category = 'Wonderful')
#             WHEN rating_category = 'Very Good' THEN h.price BETWEEN
#                 (SELECT avg_price FROM avg_price_by_rating_category WHERE rating_category = 'Very Good')
#                     AND (SELECT avg_price FROM avg_price_by_rating_category WHERE rating_category = 'Wonderful')
#         ELSE NULL END;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 95 rows affected.
# [(1, 'Amar Boutique Hotel', Decimal('9.8'), Decimal('123'), 'Wonderful', 'Pererenan', 'Canggu', 'https://www.booking.com/hotel/id/amar-boutique.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&u'),
#  (2, 'ZIN Canggu Resort & Villas', Decimal('9.4'), Decimal('144'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/zin-canggu.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs'),
#  (3, 'Villa Istana Putih by Nakula', Decimal('9.4'), Decimal('416'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/villa-istana-putih.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304'),
#  (4, 'Villa Del Mar Canggu', Decimal('9.3'), Decimal('124'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/villa-del-mar-canggu.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3'),
#  (5, 'Villa Sally', Decimal('9.3'), Decimal('292'), 'Wonderful', 'Berawa', 'Canggu', 'https://www.booking.com/hotel/id/villa-sally.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucf'),
#  (6, 'Hotel Tugu Bali - CHSE Certified', Decimal('9.1'), Decimal('201'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/tugu-bali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs='),
#  (7, 'COMO Uma Canggu - CHSE Certified', Decimal('9.1'), Decimal('241'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/como-uma-canggu.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142'),
#  (8, 'Planta Luxury Boutique Resort', Decimal('9.0'), Decimal('127'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/planta-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (9, 'Tapa Tepi Kali Echo Beach', Decimal('8.9'), Decimal('85'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/tapa-tepi-kali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (10, 'THE HAVEN SUITES Bali Berawa', Decimal('8.9'), Decimal('86'), 'Wonderful', 'Berawa', 'Canggu', 'https://www.booking.com/hotel/id/the-haven-suite-bali-berawa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea69'),
#  (11, 'Aradhana Villas by Ekosistem', Decimal('8.8'), Decimal('120'), 'Wonderful', 'Berawa', 'Canggu', 'https://www.booking.com/hotel/id/aradhana-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142'),
#  (12, 'Regali Villa Canggu', Decimal('8.6'), Decimal('116'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/regali-villa-canggu.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30'),
#  (13, 'The Bidadari Villas and Spa Umalas - CHSE Certified', Decimal('8.4'), Decimal('81'), 'Wonderful', 'Umalas', 'Canggu', 'https://www.booking.com/hotel/id/the-bidadari-luxury-villas-spa-kerobokan.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777'),
#  (14, 'The Apartments Canggu', Decimal('8.2'), Decimal('83'), 'Wonderful', 'Batu Bolong', 'Canggu', 'https://www.booking.com/hotel/id/the-apartments-canggu.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid='),
#  (15, 'Legong Keraton Beach Hotel', Decimal('7.9'), Decimal('57'), 'Very Good', 'Berawa', 'Canggu', 'https://www.booking.com/hotel/id/legong-keraton-beach.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3'),
#  (1, 'Villa Seminyak William', Decimal('9.7'), Decimal('530'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/villa-william-seminyak-bali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea69'),
#  (2, 'Blue Karma Dijiwa Seminyak', Decimal('9.4'), Decimal('118'), 'Wonderful', 'Dyanapura', 'Seminyak', 'https://www.booking.com/hotel/id/blue-karma.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs'),
#  (3, 'Sampatti Villas', Decimal('9.4'), Decimal('132'), 'Wonderful', 'Sunset Road', 'Seminyak', 'https://www.booking.com/hotel/id/sampatti-villas-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (4, 'The Dusun', Decimal('9.4'), Decimal('152'), 'Wonderful', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/the-dusun.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs='),
#  (5, 'Hotel Indigo Bali Seminyak Beach, an IHG Hotel', Decimal('9.3'), Decimal('154'), 'Wonderful', 'Dyanapura', 'Seminyak', 'https://www.booking.com/hotel/id/indigo-bali-seminyak-beach.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698'),
#  (6, 'Nyuh Bali Villas - CHSE Certified', Decimal('9.2'), Decimal('125'), 'Wonderful', 'Sunset Road', 'Seminyak', 'https://www.booking.com/hotel/id/nyuh-bali-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (7, 'The Sanyas Suite Bali', Decimal('9.2'), Decimal('128'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/the-sanyas-suite.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (8, 'Sandi Agung Villa - CHSE Certified', Decimal('9.2'), Decimal('169'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/sandi-agung-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3041'),
#  (9, 'W Bali - Seminyak', Decimal('9.2'), Decimal('338'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/w-retreat.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs='),
#  (10, 'Kanvaz Village Resort Seminyak', Decimal('9.1'), Decimal('98'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/kanvaz-village-resort-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbe'),
#  (11, 'The Daha, A luxury Resort and Spa', Decimal('9.1'), Decimal('272'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/the-daha-a-luxury-resort-and-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dc'),
#  (12, 'The Seminyak Beach Resort & Spa', Decimal('9.1'), Decimal('276'), 'Wonderful', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/the-seminyak-beach-resort-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea'),
#  (13, 'Bali Dyana Villas', Decimal('9.0'), Decimal('105'), 'Wonderful', 'Dyanapura', 'Seminyak', 'https://www.booking.com/hotel/id/bali-dyana-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3041'),
#  (14, 'Kiss Bali Villas', Decimal('9.0'), Decimal('116'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/kiss-villas-bali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (15, 'Alila Seminyak', Decimal('9.0'), Decimal('303'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/alila-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (16, 'The Seiryu Boutique Villa', Decimal('8.9'), Decimal('81'), 'Wonderful', 'Drupadi', 'Seminyak', 'https://www.booking.com/hotel/id/the-seiryu-boutique-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&'),
#  (17, 'Juada Garden', Decimal('8.9'), Decimal('83'), 'Wonderful', 'Central Seminyak', 'Seminyak', 'https://www.booking.com/hotel/id/juada-garden.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (18, 'Aria Exclusive Villas & Spa - CHSE Certified', Decimal('8.9'), Decimal('101'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/aria-luxury-villas-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid'),
#  (19, 'Bracha Villas Bali - CHSE Certified', Decimal('8.9'), Decimal('138'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/bracha-villas-bali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304'),
#  (20, 'Villa DeDayuh Seminyak', Decimal('8.9'), Decimal('160'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/villa-dedayuh-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid'),
#  (21, 'Astera Villa Seminyak', Decimal('8.9'), Decimal('173'), 'Wonderful', 'Nakula', 'Seminyak', 'https://www.booking.com/hotel/id/astera-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (22, 'Aleva Villa', Decimal('8.9'), Decimal('184'), 'Wonderful', 'Sunset Road', 'Seminyak', 'https://www.booking.com/hotel/id/aleva-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucf'),
#  (23, 'Monaco Blu Luxury Villas and Spa', Decimal('8.9'), Decimal('264'), 'Wonderful', 'Batubelig', 'Seminyak', 'https://www.booking.com/hotel/id/monaco-blu-luxury-villas-and-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dc'),
#  (24, 'Origin Seminyak', Decimal('8.8'), Decimal('94'), 'Wonderful', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/origin-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142'),
#  (25, 'Aksari Villa Seminyak', Decimal('8.8'), Decimal('173'), 'Wonderful', 'Nakula', 'Seminyak', 'https://www.booking.com/hotel/id/aksari-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (26, 'Villa Maviba', Decimal('8.8'), Decimal('300'), 'Wonderful', 'Sunset Road', 'Seminyak', 'https://www.booking.com/hotel/id/villa-maviba.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (27, 'The Light Exclusive Villas and SPA - CHSE Certified', Decimal('8.7'), Decimal('144'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/the-light-exclusive-villas-amp-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717'),
#  (28, 'The Jineng Villas by Ekosistem', Decimal('8.6'), Decimal('83'), 'Wonderful', 'Nakula', 'Seminyak', 'https://www.booking.com/hotel/id/the-jineng.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs'),
#  (28, 'IZE Seminyak', Decimal('8.6'), Decimal('83'), 'Wonderful', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/ize-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (29, 'DISINI Luxury Spa Villas-CHSE Certified', Decimal('8.6'), Decimal('93'), 'Wonderful', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/disini-luxury-spa-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (30, 'The Kasih Villas & Spa', Decimal('8.5'), Decimal('137'), 'Wonderful', 'Nakula', 'Seminyak', 'https://www.booking.com/hotel/id/the-kasih-villas-amp-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (31, 'Le Jardin Villas Seminyak', Decimal('8.3'), Decimal('158'), 'Wonderful', 'Dyanapura', 'Seminyak', 'https://www.booking.com/hotel/id/le-jardin-boutique-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&'),
#  (32, 'Singgah Villas Seminyak', Decimal('8.1'), Decimal('99'), 'Wonderful', 'Nakula', 'Seminyak', 'https://www.booking.com/hotel/id/sejuk-by-gita-ayu-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&ai'),
#  (33, 'The Yubi Boutique Villas Seminyak - CHSE Certified', Decimal('8.1'), Decimal('163'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/bali-yubi-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (34, 'Puri Saron Hotel Seminyak', Decimal('8.0'), Decimal('57'), 'Very Good', 'Dyanapura', 'Seminyak', 'https://www.booking.com/hotel/id/puri-saron-seminyak.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30'),
#  (35, 'The Jas Villas', Decimal('7.7'), Decimal('63'), 'Very Good', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/the-jas-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (36, 'New Pondok Sara Villas - CHSE Certified', Decimal('7.7'), Decimal('66'), 'Very Good', 'Double Six', 'Seminyak', 'https://www.booking.com/hotel/id/pondok-sara-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3041'),
#  (37, 'Jas Green Villas and Spa', Decimal('7.6'), Decimal('63'), 'Very Good', 'Laksmana', 'Seminyak', 'https://www.booking.com/hotel/id/jas-green-villas-and-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (1, 'Villa Sindu Ubud', Decimal('9.6'), Decimal('97'), 'Wonderful', 'Sayan', 'Ubud', 'https://www.booking.com/hotel/id/villa-sindu-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (2, 'Vije Boutique Resort & Spa', Decimal('9.6'), Decimal('110'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/vije-boutique-resort-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&'),
#  (3, 'Adiwana Unagi Suites', Decimal('9.5'), Decimal('112'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/adiwana-unagi-suites.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3'),
#  (4, 'Adiwana Suweta', Decimal('9.5'), Decimal('122'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/adiwana-suweta.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (5, 'Kuwarasan A Pramana Experience', Decimal('9.5'), Decimal('175'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/kuwarasan-a-pramana-experience.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbe'),
#  (6, 'Tejaprana Bisma - CHSE Certified', Decimal('9.5'), Decimal('498'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/tejaprana-bisma.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142'),
#  (7, 'Viceroy Bali - CHSE Certified', Decimal('9.5'), Decimal('669'), 'Wonderful', 'Andong', 'Ubud', 'https://www.booking.com/hotel/id/viceroy-bali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (8, 'The Forest Villa Ubud', Decimal('9.4'), Decimal('90'), 'Wonderful', 'Kedewatan', 'Ubud', 'https://www.booking.com/hotel/id/the-forest-villa-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid='),
#  (9, 'Komaneka at Monkey Forest Ubud', Decimal('9.4'), Decimal('110'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/komaneka-at-monkey-forest.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&'),
#  (9, 'Komaneka at Bisma Ubud', Decimal('9.4'), Decimal('110'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/komaneka-at-bisma.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3041'),
#  (10, 'The Udaya Resorts and Spa', Decimal('9.4'), Decimal('139'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/the-udaya-resorts-and-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&'),
#  (11, 'Dwaraka The Royal Villas', Decimal('9.4'), Decimal('156'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/dwaraka-the-royal-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (12, 'Royal Kamuela Villas & Suites at Monkey Forest Ubud', Decimal('9.4'), Decimal('171'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/royal-kamuela-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304'),
#  (13, 'Bisma Eight - CHSE Certified', Decimal('9.4'), Decimal('260'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/bisma-eight.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucf'),
#  (14, 'COMO Uma Ubud - CHSE Certified', Decimal('9.4'), Decimal('287'), 'Wonderful', 'Campuhan', 'Ubud', 'https://www.booking.com/hotel/id/uma-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs=1'),
#  (15, 'Sativa Villas Ubud with Private Pool', Decimal('9.3'), Decimal('159'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/sativa-villas-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304'),
#  (16, 'The Purist Villas & Spa Ubud', Decimal('9.3'), Decimal('181'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/the-purist-villas-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid='),
#  (17, 'Wegi House 2', Decimal('9.3'), Decimal('195'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/wegi-house-2.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&uc'),
#  (18, 'Villa Capung Mas Ubud', Decimal('9.3'), Decimal('290'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/villa-capung-mas-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid='),
#  (19, 'Adiwana Arkara Resort', Decimal('9.2'), Decimal('89'), 'Wonderful', 'Penestanan', 'Ubud', 'https://www.booking.com/hotel/id/arkara-villa-and-suite.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid'),
#  (20, 'Pramana Watu Kurung', Decimal('9.2'), Decimal('138'), 'Wonderful', 'Kedewatan', 'Ubud', 'https://www.booking.com/hotel/id/pramana-watu-kurung-resort.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698'),
#  (21, 'Kaamala Resort Ubud', Decimal('9.2'), Decimal('162'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/kaamala-resort-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30'),
#  (22, 'Madani Antique Villas', Decimal('9.1'), Decimal('87'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/madani-antique-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid='),
#  (23, 'The Sankara Suites and Villas by Pramana', Decimal('9.1'), Decimal('100'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/the-sankara-suite-and-villa-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dc'),
#  (24, 'Ume Sri Villas Ubud', Decimal('9.1'), Decimal('106'), 'Wonderful', 'Pengosekan', 'Ubud', 'https://www.booking.com/hotel/id/ume-sri-villas-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30'),
#  (25, 'Kastara Resort', Decimal('9.1'), Decimal('117'), 'Wonderful', 'Sambahan', 'Ubud', 'https://www.booking.com/hotel/id/kastara-resort.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (26, 'Alaya Resort Ubud - CHSE Certified', Decimal('9.1'), Decimal('118'), 'Wonderful', 'Pengosekan', 'Ubud', 'https://www.booking.com/hotel/id/alaya-resort-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3041'),
#  (27, 'Maya Ubud Resort & Spa', Decimal('9.1'), Decimal('268'), 'Wonderful', 'Peliatan', 'Ubud', 'https://www.booking.com/hotel/id/maya-ubud-resort-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3'),
#  (28, 'Kamandalu Ubud - CHSE Certified', Decimal('9.1'), Decimal('303'), 'Wonderful', 'Andong', 'Ubud', 'https://www.booking.com/hotel/id/kamandalu-resort-and-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (29, 'Natya Resort Ubud', Decimal('9.1'), Decimal('381'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/natya-resorts-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304'),
#  (30, 'Wapa di Ume Ubud', Decimal('9.0'), Decimal('89'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/waka-di-ume-resort-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid'),
#  (31, 'Pita Maha Resort & Spa', Decimal('9.0'), Decimal('183'), 'Wonderful', 'Campuhan', 'Ubud', 'https://www.booking.com/hotel/id/pita-maha-resort-spa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3'),
#  (32, 'River Sakti Ubud by Prasi', Decimal('9.0'), Decimal('605'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/river-sakti-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (33, 'Rama Phala Resort & Spa', Decimal('8.9'), Decimal('97'), 'Wonderful', 'Pengosekan', 'Ubud', 'https://www.booking.com/hotel/id/rama-phala-resort.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3041'),
#  (34, "D'Bale Ananda Ubud Villa", Decimal('8.9'), Decimal('111'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/d-39-bale-ananda-ubud-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea69'),
#  (35, 'Nang Ade Villa by Pramana Villas', Decimal('8.9'), Decimal('132'), 'Wonderful', 'Taman', 'Ubud', 'https://www.booking.com/hotel/id/nang-ade-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (36, 'Graha Sandat Villas by Pramana Villas', Decimal('8.8'), Decimal('99'), 'Wonderful', 'Ubud City-Centre', 'Ubud', 'https://www.booking.com/hotel/id/tapa-graha-sandat-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&a'),
#  (37, 'Ubud Padi Villas', Decimal('8.8'), Decimal('131'), 'Wonderful', 'Campuhan', 'Ubud', 'https://www.booking.com/hotel/id/ubud-padi-villas.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414'),
#  (38, 'Black Penny Villas Ubud', Decimal('8.8'), Decimal('199'), 'Wonderful', 'Kedewatan', 'Ubud', 'https://www.booking.com/hotel/id/black-penny-villas-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&ai'),
#  (39, 'Mathis Retreat Ubud', Decimal('8.2'), Decimal('95'), 'Wonderful', 'Campuhan', 'Ubud', 'https://www.booking.com/hotel/id/mathis-retreat.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&'),
#  (40, 'Umae Villa Ubud', Decimal('8.0'), Decimal('61'), 'Very Good', 'Pengosekan', 'Ubud', 'https://www.booking.com/hotel/id/umae-villa.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&ucfs'),
#  (41, 'Amatara Agung Raka', Decimal('7.8'), Decimal('59'), 'Very Good', 'Pengosekan', 'Ubud', 'https://www.booking.com/hotel/id/agung-raka-bungalows.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=3')]

# %% [markdown]
# #### Recommendations
# Narrow down our options further for the customer.

# %% [markdown]
# ### 3b. Which hotels should we recommend to Customer X?
#
# #### Business Justification
# We know that Customer X was interested in this new service because they were overwhelmed by the process of searching through pages of hotels. Expanding from the previous query, we should limit the list of hotel options to the top hotel from each district.

# %%
# %%sql
# WITH ranked_curated_hotels AS (
#     SELECT
#         DENSE_RANK() OVER (
#             PARTITION BY district_name
#             ORDER BY rating DESC, h.price
#         ) AS ranking,
#         name,
#         h.rating,
#         h.price,
#         rating_category,
#         subdistrict_name AS subdistrict,
#         district_name AS district,
#         link
#     FROM hotels h
#     JOIN district d
#         ON h.district = d.district_id
#     JOIN subdistrict s
#         ON h.subdistrict = s.subdistrict_id
#     JOIN hotel_rating_category hs
#         ON h.hotel_id = hs.hotel_id
#     WHERE district_name IN ('Ubud', 'Seminyak', 'Canggu')
#         AND CASE
#                 WHEN rating_category = 'Wonderful' THEN h.price >=
#                     (SELECT avg_price FROM avg_price_by_rating_category WHERE rating_category = 'Wonderful')
#                 WHEN rating_category = 'Very Good' THEN h.price BETWEEN
#                     (SELECT avg_price FROM avg_price_by_rating_category WHERE rating_category = 'Very Good')
#                         AND (SELECT avg_price FROM avg_price_by_rating_category WHERE rating_category = 'Wonderful')
#             ELSE NULL END
# )
# SELECT *
# FROM ranked_curated_hotels
# WHERE ranking = 1
# ORDER BY rating DESC;
# Out:
#  * mysql+mysqldb://admin:***@bali-hotels.cj8fr6zjuwf1.us-east-1.rds.amazonaws.com/bali_hotels?charset=utf8
# 3 rows affected.
# [(1, 'Amar Boutique Hotel', Decimal('9.8'), Decimal('123'), 'Wonderful', 'Pererenan', 'Canggu', 'https://www.booking.com/hotel/id/amar-boutique.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=304142&u'),
#  (1, 'Villa Seminyak William', Decimal('9.7'), Decimal('530'), 'Wonderful', 'Petitenget', 'Seminyak', 'https://www.booking.com/hotel/id/villa-william-seminyak-bali.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea69'),
#  (1, 'Villa Sindu Ubud', Decimal('9.6'), Decimal('97'), 'Wonderful', 'Sayan', 'Ubud', 'https://www.booking.com/hotel/id/villa-sindu-ubud.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaIkCiAEBmAExuAEHyAEM2AED6AEB-AECiAIBqAIDuALHr62SBsACAdICJDA2ZTc1ZjZlLTZkNTQtNGU1MC04ZTFkLTkxZWVhMDQwMmU5NtgCBOACAQ&sid=79ebc94bece7803777ea9717dcbea698&aid=30414')]

# %% [markdown]
# #### Recommendations
# 1. Now that we have the curated list of hotels for Customer X we should present these options to the customer. Once the customer approves of a hotel, we can guide them through the process of booking the hotel directly through the site. For the purpose of these tests, these queries can be modified for other customers.
#
# 2. The data science and analytics team should collaborate with the engineering team to develop an algorithm and program that can be used by the travel specialists to simplify this process.

# %%
# !nbmerge data_collection.ipynb sql_analysis.ipynb > presentation.ipynb
